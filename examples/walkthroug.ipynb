# %% [markdown]
# # Walkthrough
# Follow this walkthrough to see each table you are able to access

# %%
from pywsl import (
    get_league_table,
    get_fixtures,
    get_top_scorers,
    get_squad_valuations,
    get_venue_attendance,
    display_table
)

# %% [markdown]
# ## Top goal scorers
# Get top goal scorers for 2024

# %%
scorers_df = get_top_scorers("2024")
scorers_df
# Out:
#                   Name                    Club Age Matches Sub On Sub Off  \
# 0         Khadija Shaw         Manchester City  28      14      4       5
# 1        Alessia Russo              Arsenal FC  26      21      2       4
# 2    Shekiera Martinez         West Ham United  23      12      1       7
# 3    Elisabeth Terland       Manchester United  23      20      2       9
# 4       Viviane Asseyi         West Ham United  31      21      0       8
# 5   Aggie Beever-Jones              Chelsea FC  21      22     10       6
# 6    Mariona Caldentey              Arsenal FC  29      21      1       8
# 7         Beth England       Tottenham Hotspur  31      19      4       3
# 8          Guro Reiten              Chelsea FC  30      17      4       8
# 9          Rachel Daly             Aston Villa  33      22      0      10
# 10       Grace Clinton       Manchester United  22      21      2       5
# 11    Vivianne Miedema         Manchester City  28      11      3       6
# ...

# %% [markdown]
# ## Get Fixtures
# Returns a table of previous and upcoming fixture

# %%
fixtures_df = get_fixtures()
fixtures_df
# Out:
#     Matchday        Date        Home Team        Away Team Score
# 0          1  20.09.2024       Chelsea FC      Aston Villa   1:0
# 1          1  21.09.2024   Manchester Utd  West Ham United   3:0
# 2          1  21.09.2024  Brighton & Hove       Everton FC   4:0
# 3          1  22.09.2024       Arsenal FC  Manchester City   2:2
# 4          1  22.09.2024        Tottenham   Crystal Palace   4:0
# ..       ...         ...              ...              ...   ...
# 127       22  10.05.2025   Leicester City  West Ham United   4:2
# 128       22  10.05.2025       Everton FC        Tottenham   1:1
# 129       22  10.05.2025       Chelsea FC     Liverpool FC   1:0
# 130       22  10.05.2025      Aston Villa  Brighton & Hove   3:1
# 131       22  10.05.2025       Arsenal FC   Manchester Utd   4:3
#
# [132 rows x 5 columns]

# %% [markdown]
# ## Get squad information
# Returns squad valuations

# %%
squad_df = get_squad_valuations()
squad_df
# Out:
#                       Club  Squad Size  Avg Age Market Value (€)  \
# 0               Chelsea FC          34     25.3      5,155,000 €
# 1               Arsenal FC          26     27.0      4,220,000 €
# 2          Manchester City          31     24.3      3,590,000 €
# 3        Manchester United          27     24.9      2,190,000 €
# 4        Tottenham Hotspur          29     26.4      1,680,000 €
# 5             Liverpool FC          29     25.1      1,560,000 €
# 6              Aston Villa          26     26.4      1,480,000 €
# 7               Everton FC          36     25.4      1,435,000 €
# 8   Brighton & Hove Albion          31     26.0      1,265,000 €
# 9           Leicester City          31     24.1      1,150,000 €
# 10         West Ham United          25     26.8      1,030,000 €
# 11          Crystal Palace          26     26.3        845,000 €
#
#    Avg Value/Player (€) Market Value (GBP) Avg Value/Player (GBP)
# ...

# %% [markdown]
# ## Get venue information
# This returns venue attendances for any given year

# %%
venue_df = get_venue_attendance("2024")
venue_df
# Out:
#                       Club                             Stadium  Capacity  \
# 0               Arsenal FC                         Meadow Park      4502
# 1               Arsenal FC                    Emirates Stadium     60704
# 2              Aston Villa                          Villa Park     42095
# 3   Brighton & Hove Albion  American Express Community Stadium     31800
# 4   Brighton & Hove Albion                  Broadfield Stadium      6134
# 5               Chelsea FC                         Kingsmeadow      4850
# 6               Chelsea FC                     Stamford Bridge     41837
# 7           Crystal Palace                       Selhurst Park     25486
# 8           Crystal Palace               VBS Community Stadium      7032
# 9               Everton FC                    Walton Hall Park      1000
# 10              Everton FC                       Goodison Park     39414
# 11          Leicester City                  King Power Stadium     32261
# ...

# %% [markdown]
# ## Get League Table
# Returns current league table

# %%
league_df = get_league_table()
league_df
# Out:
#    Position                    Team  Matches  Wins  Draws  Losses  Goals For  \
# 0         1              Chelsea FC       22    19      3       0         56
# 1         2              Arsenal FC       22    15      3       4         62
# 2         3       Manchester United       22    13      5       4         41
# 3         4         Manchester City       22    13      4       5         49
# 4         5  Brighton & Hove Albion       22     8      4      10         35
# 5         6             Aston Villa       22     7      4      11         32
# 6         7            Liverpool FC       22     7      4      11         22
# 7         8              Everton FC       22     6      6      10         24
# 8         9         West Ham United       22     6      5      11         36
# 9        10          Leicester City       22     5      5      12         21
# 10       11       Tottenham Hotspur       22     5      5      12         26
# ...
